# %% [markdown]
# # Import packages and data

# %%
import pandas as pd
import numpy as np

# %%
POLICY_DATA = '../data/datastorm_policy_data.csv'
AGENT_DATA = '../data/datastorm_agent_data.csv'

# %%
df = pd.read_csv(POLICY_DATA, parse_dates=['next_due_dt', 'termination_dt', 
                                           'main_holder_dob', 'spouse_dob', 
                                           'child1_dob', 'child2_dob', 
                                           'child3_dob', 'child4_dob', 
                                           'child5_dob', 
                                           'run_date' ])
# Out:
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.drop(columns=['main_holder_occupation_cd', 'product_code'])

# %%
df.head()
# Out:
#    policy_term policy_payment_mode policy_status commencement_dt next_due_dt  \
# 0           20                   M       INFORCE      2011/08/21  2019-02-21
# 1           15                   M       INFORCE      2006/07/14  2019-09-14
# 2           20                   Y       INFORCE      2018/12/28  2019-12-28
# 3           15                   Q       INFORCE      2018/11/06  2020-02-06
# 4           15                   M        LAPSED      2012/04/28  2015-06-28
#
#   termination_dt termination_reason main_holder_gender main_holder_dob  \
# 0            NaT                NaN                  M      1983-10-01
# 1            NaT                NaN                  F      1958-01-01
# 2            NaT                NaN                  M      1967-11-01
# 3            NaT                NaN                  M      1989-10-01
# 4            NaT             OTHERS                  M      1988-05-01
#
#    main_holder_entry_age  ... child5_dob child5_gender payment_method  \
# 0                     28  ...        NaT           NaN           CASH
# 1                     48  ...        NaT           NaN           CASH
# 2                     51  ...        NaT           NaN           CASH
# 3                     29  ...        NaT           NaN         CHEQUE
# 4                     24  ...        NaT           NaN           CASH
#
#    main_holder_occupation policy_snapshot_as_on   run_date  client_code  \
# 0                     NaN              20190131 2020-07-01      C108223
# 1             BUSINESSMAN              20190901 2020-07-01      C103349
# 2          RECYCLE RACERS              20191101 2020-07-01      C120388
# 3            RECEPTIONIST              20191201 2020-07-01      C113155
# 4             BUSINESSMAN              20190228 2020-07-01      C106155
#
#    agent_code  product_name  policy_code
# 0    AG108847        HEALTH     POL28535
# 1    AG103677    RETIREMENT     POL27771
# 2    AG103249    INVESTMENT     POL29786
# 3    AG106733        HEALTH     POL24635
# 4    AG106907        HEALTH      POL7470
#
# [5 rows x 55 columns]

# %% [markdown]
# # Create Labels

# %%
def create_labels(df, train_snap_date, label_last_date):
    snap_df = df[(df.policy_snapshot_as_on == train_snap_date) 
                    & (df.policy_status == 'INFORCE')][['client_code', 
                                                        'policy_code', 
                                                        'product_name']]
    cust_df = snap_df[['client_code']].drop_duplicates().set_index('client_code')
    print(cust_df)
    label_df = df[(df.policy_snapshot_as_on > train_snap_date) 
                     & (df.policy_snapshot_as_on <= label_last_date) 
                     & (df.policy_status == 'INFORCE')][['client_code', 
                                                         'product_name', 
                                                         'policy_code', 
                                                         'policy_snapshot_as_on']]
    
    join_df = label_df.merge(snap_df[['policy_code', 'client_code']], on=['policy_code', 'client_code'], how='left', indicator=True)
    join_df['is_prev'] = join_df._merge.map({'left_only':0, 'both':1}).astype(int)
    
    #customers who can be c
    cross_sell_eligible = join_df.groupby(['client_code', 'policy_snapshot_as_on']).is_prev.sum()
    
    cross_sell_eligible.name = 'cross_sell_eligible'
    cross_sell_eligible = cross_sell_eligible[cross_sell_eligible > 0].reset_index()
    
    joined_cs_eligible = join_df.merge(cross_sell_eligible, on=['client_code', 'policy_snapshot_as_on'], how='left').dropna()
    
    labels = joined_cs_eligible[joined_cs_eligible.is_prev == 0][['client_code', 'product_name']].drop_duplicates()
    labels['value'] = 1
    pivot_labels = labels.pivot_table(values='value', index='client_code', aggfunc='sum', columns='product_name').fillna(0).astype(int)

    return cust_df.merge(pivot_labels, on='client_code', how='left').fillna(0)

# %% [markdown]
# # Create Client Dataset

# %%
def client_dataset(df, snap_date):
    df_snap = df[(df.policy_snapshot_as_on == snap_date) & (df.policy_status == 'INFORCE')]
    
    customer_specific_features = ['main_holder_gender', 'main_holder_dob',
                              'main_holder_smoker_flag', 'spouse_gender',
                               'spouse_dob', 'spouse_smoker_flag',
                               'child1_dob', 'child1_gender', 'child2_dob',
                               'child2_gender', 'child3_dob', 'child3_gender', 'child4_dob',
                               'child4_gender', 'child5_dob', 'child5_gender',
                               'main_holder_occupation', 
                               'client_code']
    
    df_cust = df_snap[customer_specific_features]

    dob_feat = ['main_holder_dob', 'spouse_dob', 'child1_dob', 'child2_dob',
           'child3_dob', 'child4_dob', 'child5_dob']

    age_feat = []
    for col in dob_feat:
        new_col = col[:-4] + '_age'
        df_cust[new_col] = pd.to_datetime(snap_date, format='%Y%m%d').year - df_cust[col].dt.year
        df_cust = df_cust.drop(columns=col)
        age_feat.append(new_col)

    df_cust_numeric = df_cust.groupby('client_code')[age_feat].median()

    df_cust_cat = df_cust.select_dtypes('object').groupby('client_code').first()

    df_cust_fin = df_cust_cat.join(df_cust_numeric)
    
    return df_cust_fin

# %%
snap_date = 20181231

# %%
df_snap = df[(df.policy_snapshot_as_on == snap_date) & (df.policy_status == 'INFORCE')]

# %%
customer_specific_features = ['main_holder_gender', 'main_holder_dob',
                              'main_holder_smoker_flag', 'spouse_gender',
                               'spouse_dob', 'spouse_smoker_flag',
                               'child1_dob', 'child1_gender', 'child2_dob',
                               'child2_gender', 'child3_dob', 'child3_gender', 'child4_dob',
                               'child4_gender', 'child5_dob', 'child5_gender',
                               'main_holder_occupation', 
                               'client_code']

# %%
df_cust = df_snap[customer_specific_features]

dob_feat = ['main_holder_dob', 'spouse_dob', 'child1_dob', 'child2_dob',
       'child3_dob', 'child4_dob', 'child5_dob']

age_feat = []
for col in dob_feat:
    new_col = col[:-4] + '_age'
    df_cust[new_col] = pd.to_datetime(snap_date, format='%Y%m%d').year - df_cust[col].dt.year
    df_cust = df_cust.drop(columns=col)
    age_feat.append(new_col)

df_cust_numeric = df_cust.groupby('client_code')[age_feat].median()

df_cust_cat = df_cust.select_dtypes('object').groupby('client_code').first()

df_cust_fin = df_cust_cat.join(df_cust_numeric)

# %%
df_cust_fin
# Out:
#             main_holder_gender main_holder_smoker_flag spouse_gender  \
# client_code
# C100000                      M                       N           NaN
# C100001                      M                       N           NaN
# C100002                      M                       N           NaN
# C100003                      F                       N           NaN
# C100004                      F                       N           NaN
# ...                        ...                     ...           ...
# C154407                      F                       N           NaN
# C154416                      F                       N           NaN
# C154436                      F                       N           NaN
# C154442                      M                       N           NaN
# C154448                      M                       N           NaN
#
#             spouse_smoker_flag child1_gender child2_gender child3_gender  \
# client_code
# C100000                    NaN           NaN           NaN           NaN
# C100001                    NaN           NaN           NaN           NaN
# C100002                    NaN           NaN           NaN           NaN
# C100003                    NaN           NaN           NaN           NaN
# C100004                    NaN           NaN           NaN           NaN
# ...                        ...           ...           ...           ...
# C154407                    NaN           NaN           NaN           NaN
# C154416                    NaN           NaN           NaN           NaN
# C154436                    NaN           NaN           NaN           NaN
# C154442                    NaN           NaN           NaN           NaN
# C154448                    NaN           NaN           NaN           NaN
#
#             child4_gender child5_gender main_holder_occupation  \
# client_code
# C100000               NaN           NaN   FLOUR & GRAIN MILL W
# C100001               NaN           NaN       CHENA CULTIVATOR
# C100002               NaN           NaN   FLOUR & GRAIN MILL W
# C100003               NaN           NaN               MINISTER
# C100004               NaN           NaN               MINISTER
# ...                   ...           ...                    ...
# C154407               NaN           NaN               SALESMAN
# C154416               NaN           NaN               SALESMAN
# C154436               NaN           NaN                    NaN
# C154442               NaN           NaN            BUSINESSMAN
# C154448               NaN           NaN                ADVISOR
#
#              main_holder_age  spouse_age  child1_age  child2_age  child3_age  \
# client_code
# C100000                 27.0         NaN         NaN         NaN         NaN
# C100001                 37.0         NaN         NaN         NaN         NaN
# C100002                 24.0         NaN         NaN         NaN         NaN
# C100003                 27.0         NaN         NaN         NaN         NaN
# C100004                 46.0         NaN         NaN         NaN         NaN
# ...                      ...         ...         ...         ...         ...
# C154407                 39.0         NaN         NaN         NaN         NaN
# C154416                 30.0         NaN         NaN         NaN         NaN
# C154436                 47.0         NaN         NaN         NaN         NaN
# C154442                 35.0         NaN         NaN         NaN         NaN
# C154448                 19.0         NaN         NaN         NaN         NaN
#
#              child4_age  child5_age
# client_code
# C100000             NaN         NaN
# C100001             NaN         NaN
# C100002             NaN         NaN
# C100003             NaN         NaN
# C100004             NaN         NaN
# ...                 ...         ...
# C154407             NaN         NaN
# C154416             NaN         NaN
# C154436             NaN         NaN
# C154442             NaN         NaN
# C154448             NaN         NaN
#
# [19271 rows x 17 columns]

# %%
df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     662         try:
# --> 663             return self._aggregate_series_fast(obj, func)
#     664         except Exception:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     680         grouper = reduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 681         result, counts = grouper.get_result()
#     682         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#
# <ipython-input-173-0d7357b2b66b> in <lambda>(x)
# ----> 1 df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     862             try:
# --> 863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     899             try:
# --> 900                 result, counts = self.grouper.agg_series(obj, f)
#     901                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     664         except Exception:
# --> 665             return self._aggregate_series_pure_python(obj, func)
#     666
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     693         for label, group in splitter:
# --> 694             res = func(group)
#     695             if result is None:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#
# <ipython-input-173-0d7357b2b66b> in <lambda>(x)
# ----> 1 df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     243                     result = self._aggregate_multiple_funcs(
# --> 244                         [func], _level=_level, _axis=self.axis
#     245                     )
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     608                     colg = self._gotitem(col, ndim=1, subset=obj.iloc[:, index])
# --> 609                     results.append(colg.aggregate(arg))
#     610                     keys.append(col)
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     850             func_or_funcs = _maybe_mangle_lambdas(func_or_funcs)
# --> 851             ret = self._aggregate_multiple_funcs(func_or_funcs, (_level or 0) + 1)
#     852             if relabeling:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     929                 obj._selection = name
# --> 930             results[name] = obj.aggregate(func)
#     931
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     864             except Exception:
# --> 865                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     866
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     996             group.name = name
# --> 997             output = func(group, *args, **kwargs)
#     998             if isinstance(output, (Series, Index, np.ndarray)):
#
# <ipython-input-173-0d7357b2b66b> in <lambda>(x)
# ----> 1 df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_generic(self, func, *args, **kwargs)
#     281                 for name, data in self:
# --> 282                     result[name] = self._try_cast(func(data, *args, **kwargs), data)
#     283             except Exception:
#
# <ipython-input-173-0d7357b2b66b> in <lambda>(x)
# ----> 1 df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in mode(self, dropna)
#    1927         # TODO: Add option for bins like value_counts()
# -> 1928         return algorithms.mode(self, dropna=dropna)
#    1929
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\algorithms.py in mode(values, dropna)
#     860
# --> 861     values = _ensure_arraylike(values)
#     862     original = values
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\algorithms.py in _ensure_arraylike(values)
#     207                 values = list(values)
# --> 208             values = construct_1d_object_array_from_listlike(values)
#     209         else:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_object_array_from_listlike(values)
#    1259     result = np.empty(len(values), dtype="object")
# -> 1260     result[:] = values
#    1261     return result
#
# ValueError: could not broadcast input array from shape (11) into shape (1)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     662         try:
# --> 663             return self._aggregate_series_fast(obj, func)
#     664         except Exception:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     680         grouper = reduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 681         result, counts = grouper.get_result()
#     682         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#
# <ipython-input-173-0d7357b2b66b> in <lambda>(x)
# ----> 1 df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     862             try:
# --> 863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     899             try:
# --> 900                 result, counts = self.grouper.agg_series(obj, f)
#     901                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     664         except Exception:
# --> 665             return self._aggregate_series_pure_python(obj, func)
#     666
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     693         for label, group in splitter:
# --> 694             res = func(group)
#     695             if result is None:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#
# <ipython-input-173-0d7357b2b66b> in <lambda>(x)
# ----> 1 df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-173-0d7357b2b66b> in <module>
# ----> 1 df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     255                         result = SparseDataFrame(result._data)
#     256                 except Exception:
# --> 257                     result = self._aggregate_generic(func, *args, **kwargs)
#     258
#     259         if not self.as_index:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_generic(self, func, *args, **kwargs)
#     282                     result[name] = self._try_cast(func(data, *args, **kwargs), data)
#     283             except Exception:
# --> 284                 return self._aggregate_item_by_item(func, *args, **kwargs)
#     285         else:
#     286             for name in self.indices:
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_item_by_item(self, func, *args, **kwargs)
#     311                 cast = self._transform_should_cast(func)
#     312
# --> 313                 result[item] = colg.aggregate(func, *args, **kwargs)
#     314                 if cast:
#     315                     result[item] = self._try_cast(result[item], data)
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
# --> 865                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     866
#     867             index = Index(sorted(result), name=self.grouper.names[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     995         for name, group in self:
#     996             group.name = name
# --> 997             output = func(group, *args, **kwargs)
#     998             if isinstance(output, (Series, Index, np.ndarray)):
#     999                 raise Exception("Must produce aggregated value")
#
# <ipython-input-173-0d7357b2b66b> in <lambda>(x)
# ----> 1 df_cust.select_dtypes('object').groupby('client_code').agg(lambda x: pd.Series.mode(x)[0])
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# c:\users\nisal_105136\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4734
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#    4738                 raise
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds

# %%
df_cust.groupby()
# Out:
#         main_holder_occupation_cd main_holder_gender main_holder_dob  \
# 0                           249.0                  M      1983/10/01
# 1                           165.0                  F      1958/01/01
# 2                           330.0                  M      1967/11/01
# 3                           415.0                  M      1989/10/01
# 4                           165.0                  M      1988/05/01
# ...                           ...                ...             ...
# 631417                      354.0                  M      1981/07/01
# 631418                      165.0                  M      1982/11/01
# 631419                      306.0                  M      1958/05/01
# 631420                      481.0                  F      1992/10/01
# 631421                      165.0                  M      1987/04/01
#
#        main_holder_smoker_flag spouse_gender  spouse_dob spouse_smoker_flag  \
# 0                            N             F  1989/03/01                  N
# 1                            N           NaN         NaN                NaN
# 2                            N           NaN         NaN                NaN
# 3                            N           NaN         NaN                NaN
# 4                            N           NaN         NaN                NaN
# ...                        ...           ...         ...                ...
# 631417                       N             F  1987/08/01                  N
# 631418                       N           NaN         NaN                NaN
# 631419                       Y           NaN         NaN                NaN
# 631420                       N           NaN         NaN                NaN
# 631421                       N           NaN         NaN                NaN
#
#        child1_dob child1_gender child2_dob child2_gender child3_dob  \
# 0             NaN           NaN        NaN           NaN        NaN
# 1             NaN           NaN        NaN           NaN        NaN
# 2             NaN           NaN        NaN           NaN        NaN
# 3             NaN           NaN        NaN           NaN        NaN
# 4             NaN           NaN        NaN           NaN        NaN
# ...           ...           ...        ...           ...        ...
# 631417        NaN           NaN        NaN           NaN        NaN
# 631418        NaN           NaN        NaN           NaN        NaN
# 631419        NaN           NaN        NaN           NaN        NaN
# 631420        NaN           NaN        NaN           NaN        NaN
# 631421        NaN           NaN        NaN           NaN        NaN
#
#        child3_gender child4_dob child4_gender child5_dob child5_gender  \
# 0                NaN        NaN           NaN        NaN           NaN
# 1                NaN        NaN           NaN        NaN           NaN
# 2                NaN        NaN           NaN        NaN           NaN
# 3                NaN        NaN           NaN        NaN           NaN
# 4                NaN        NaN           NaN        NaN           NaN
# ...              ...        ...           ...        ...           ...
# 631417           NaN        NaN           NaN        NaN           NaN
# 631418           NaN        NaN           NaN        NaN           NaN
# 631419           NaN        NaN           NaN        NaN           NaN
# 631420           NaN        NaN           NaN        NaN           NaN
# 631421           NaN        NaN           NaN        NaN           NaN
#
#        main_holder_occupation client_code
# 0                         NaN     C108223
# 1                 BUSINESSMAN     C103349
# 2              RECYCLE RACERS     C120388
# 3                RECEPTIONIST     C113155
# 4                 BUSINESSMAN     C106155
# ...                       ...         ...
# 631417                MAHOUTS     C109432
# 631418            BUSINESSMAN     C113916
# 631419              QUARRYMEN     C104807
# 631420                    NaN     C148592
# 631421            BUSINESSMAN     C112321
#
# [631422 rows x 19 columns]

# %%
df.agent_code.nunique()
# Out:
# 4665

# %%
create_labels(df, 20181231, 20190630)
# Out:
# product_name  EDUCATION  HEALTH  INVESTMENT  PROTECTION  RETIREMENT
# client_code
# C100121               0       1           0           0           0
# C100132               0       1           0           0           0
# C100133               0       0           1           0           0
# C100443               0       0           1           0           0
# C100446               0       0           1           0           0
# ...                 ...     ...         ...         ...         ...
# C146490               0       0           1           0           0
# C147263               0       0           1           0           0
# C147285               0       1           0           0           0
# C147525               0       1           0           0           0
# C152762               0       1           0           0           0
#
# [525 rows x 5 columns]
